# %% [markdown]
# ## Đổi từ dạng số sang dạng tiền

# %%
print('Bắt đầu chạy chương trình:')
def VND(number):
    stringNumber = str(int(number))
    money = ''
    for i in range(len(stringNumber)):
        if (len(stringNumber) - i) % 3 == 0 and i != 0:
            money += '.'
        money+=stringNumber[i]
    money += 'đ'
    return money
print("10%")

# %% [markdown]
# ## Đổi số sang chữ - Nguồn https://ideone.com/OZJ7oa và https://daynhauhoc.com/t/challenge-doc-so-va-viet-so/58832/13

# %%
one_digit = ["không", "một", "hai", "ba", "bốn", "năm", "sáu", "bảy", "tám", "chín"]
units = ["", " mốt", " hai", " ba", " bốn", " lăm", " sáu", " bảy", " tám", " chín"]
tens = ["lẻ", "mười"] + [x + " mươi" for x in ["hai", "ba", "bốn", "năm", "sáu", "bảy", "tám", "chín"]]
hundreds = [x + " trăm" for x in one_digit]
bigger = ["", " nghìn", " triệu", " tỉ", " nghìn tỉ", " triệu tỉ", " tỉ tỉ"]
 
def read_class(s):
	n = int(s)
	if len(s) == 1:
		return one_digit[n]
	elif len(s) == 2:
		if s == '11':
			return tens[n//10] + ' một' 
		return tens[n//10] + units[n%10]
	else:  # len(s) == 3
		if s == '000':
			return ''
		elif (n//10)%10 == 0:  # x0y
			if n % 10 == 0:  # x00
				return hundreds[n//100]
			else:
				return hundreds[n//100] + ' ' + tens[(n//10)%10] + ' ' + one_digit[n%10]
		else:  # xyz
			if n%100 == 11:
				return hundreds[n//100] + ' ' + tens[(n//10)%10] + ' một'
			return hundreds[n//100] + ' ' + tens[(n//10)%10] + units[n%10]
 
def Convert(s):
	if (s == '0'):
		return 'Không đồng'
	s = s.lstrip('0').rstrip('\n')
	classes = []
	for i in range(len(s)-1, 1, -3):
		classes.append(s[i-2:i+1])
	if len(s) % 3 != 0:
		classes.append(s[:len(s)%3])
	res = ''
	for i in range(len(classes)):
		named_class = read_class(classes[i])
		if named_class != '':
			res = named_class + bigger[i] + (' ' * (res != '')) + res
	res_new = res[0].upper() + res[1:] + ' đồng'
	return res_new
print('20%')
# Out:
# 'Một triệu hai trăm ba mươi hai nghìn một trăm hai mươi ba đồng'

# %% [markdown]
# # Danh Sách Tên

# %%
import xlrd
import datetime

data = xlrd.open_workbook('Dữ liệu đầu vào.xls')
sh = data.sheet_by_index(0)
# Ten doanh nghiep, dia chi, Giam doc, Ke toan truong, Nguoi lap Phieu, Thu quy
# arr [0                1       2           3               4               5]
arr = [sh.row(i)[2].value for i in range(1,7)] 
print('30%')
# Out:
# The number of worksheets is 2
# Worksheet name(s): ['sheet 1', 'Sheet1 (2)']
# sheet 1 7 3
# ['Công ty TNHH TM & DV Ôtô Trí Minh',
#  'Lô B11-01, Lê Quý Đôn, TP Tam Kỳ, Quảng Nam',
#  'Huỳnh Văn Phát',
#  'Nguyễn .T. Thái Thanh',
#  '',
#  '']

# %% [markdown]
# # Phieu Chi and SO QUY TIEN MĂT 2017

# %%
ex = xlrd.open_workbook('ex.xls', formatting_info=True)
sh2 = ex.sheet_by_index(0)

# sh2.cell(0,0),       # Ten doanh nghiep
# sh2.cell(2, 0),      # Dia chi
# sh2.cell(21, 3),     # Nguoi lap Phieu
# sh2.cell(21, 6),     # Thu quy
# sh2.cell(21, 14),    # Ke toan truong
# sh2.cell(21, 20)     # Giam doc

qt = data.sheet_by_index(1)
print('40%')
# Out:
# The number of worksheets is 256
# Worksheet name(s): ['Sheet1 (129)', 'Sheet1 (130)', 'Sheet1 (131)', 'Sheet1 (132)', 'Sheet1 (133)', 'Sheet1 (134)', 'Sheet1 (135)', 'Sheet1 (136)', 'Sheet1 (137)', 'Sheet1 (138)', 'Sheet1 (139)', 'Sheet1 (140)', 'Sheet1 (141)', 'Sheet1 (142)', 'Sheet1 (143)', 'Sheet1 (144)', 'Sheet1 (145)', 'Sheet1 (146)', 'Sheet1 (147)', 'Sheet1 (148)', 'Sheet1 (149)', 'Sheet1 (150)', 'Sheet1 (151)', 'Sheet1 (152)', 'Sheet1 (153)', 'Sheet1 (154)', 'Sheet1 (155)', 'Sheet1 (156)', 'Sheet1 (157)', 'Sheet1 (158)', 'Sheet1 (159)', 'Sheet1 (160)', 'Sheet1 (161)', 'Sheet1 (162)', 'Sheet1 (163)', 'Sheet1 (164)', 'Sheet1 (165)', 'Sheet1 (166)', 'Sheet1 (167)', 'Sheet1 (168)', 'Sheet1 (169)', 'Sheet1 (170)', 'Sheet1 (171)', 'Sheet1 (172)', 'Sheet1 (173)', 'Sheet1 (174)', 'Sheet1 (175)', 'Sheet1 (176)', 'Sheet1 (177)', 'Sheet1 (178)', 'Sheet1 (179)', 'Sheet1 (180)', 'Sheet1 (181)', 'Sheet1 (182)', 'Sheet1 (183)', 'Sheet1 (184)', 'Sheet1 (185)', 'Sheet1 (186)', 'Sheet1 (187)', 'Sheet1 (188)', 'Sheet1 (189)', 'Sheet1 (190)', 'Sheet1 (191)', 'Sheet1 (192)', 'Sheet1 (193)', 'Sheet1 (194)', 'Sheet1 (195)', 'Sheet1 (196)', 'Sheet1 (197)', 'Sheet1 (198)', 'Sheet1 (199)', 'Sheet1 (200)', 'Sheet1 (201)', 'Sheet1 (202)', 'Sheet1 (203)', 'Sheet1 (204)', 'Sheet1 (205)', 'Sheet1 (206)', 'Sheet1 (207)', 'Sheet1 (208)', 'Sheet1 (209)', 'Sheet1 (210)', 'Sheet1 (211)', 'Sheet1 (212)', 'Sheet1 (213)', 'Sheet1 (214)', 'Sheet1 (215)', 'Sheet1 (216)', 'Sheet1 (217)', 'Sheet1 (218)', 'Sheet1 (219)', 'Sheet1 (220)', 'Sheet1 (221)', 'Sheet1 (222)', 'Sheet1 (223)', 'Sheet1 (224)', 'Sheet1 (225)', 'Sheet1 (226)', 'Sheet1 (227)', 'Sheet1 (228)', 'Sheet1 (229)', 'Sheet1 (230)', 'Sheet1 (231)', 'Sheet1 (232)', 'Sheet1 (233)', 'Sheet1 (234)', 'Sheet1 (235)', 'Sheet1 (236)', 'Sheet1 (237)', 'Sheet1 (238)', 'Sheet1 (239)', 'Sheet1 (240)', 'Sheet1 (241)', 'Sheet1 (242)', 'Sheet1 (243)', 'Sheet1 (244)', 'Sheet1 (245)', 'Sheet1 (246)', 'Sheet1 (247)', 'Sheet1 (248)', 'Sheet1 (249)', 'Sheet1 (250)', 'Sheet1 (251)', 'Sheet1 (252)', 'Sheet1 (253)', 'Sheet1 (254)', 'Sheet1 (255)', 'Sheet1 (256)', 'Sheet1 (65)', 'Sheet1 (66)', 'Sheet1 (67)', 'Sheet1 (68)', 'Sheet1 (69)', 'Sheet1 (70)', 'Sheet1 (71)', 'Sheet1 (72)', 'Sheet1 (73)', 'Sheet1 (74)', 'Sheet1 (75)', 'Sheet1 (76)', 'Sheet1 (77)', 'Sheet1 (78)', 'Sheet1 (79)', 'Sheet1 (80)', 'Sheet1 (81)', 'Sheet1 (82)', 'Sheet1 (83)', 'Sheet1 (84)', 'Sheet1 (85)', 'Sheet1 (86)', 'Sheet1 (87)', 'Sheet1 (88)', 'Sheet1 (89)', 'Sheet1 (90)', 'Sheet1 (91)', 'Sheet1 (92)', 'Sheet1 (93)', 'Sheet1 (94)', 'Sheet1 (95)', 'Sheet1 (96)', 'Sheet1 (97)', 'Sheet1 (98)', 'Sheet1 (99)', 'Sheet1 (100)', 'Sheet1 (101)', 'Sheet1 (102)', 'Sheet1 (103)', 'Sheet1 (104)', 'Sheet1 (105)', 'Sheet1 (106)', 'Sheet1 (107)', 'Sheet1 (108)', 'Sheet1 (109)', 'Sheet1 (110)', 'Sheet1 (111)', 'Sheet1 (112)', 'Sheet1 (113)', 'Sheet1 (114)', 'Sheet1 (115)', 'Sheet1 (116)', 'Sheet1 (117)', 'Sheet1 (118)', 'Sheet1 (119)', 'Sheet1 (120)', 'Sheet1 (121)', 'Sheet1 (122)', 'Sheet1 (123)', 'Sheet1 (124)', 'Sheet1 (125)', 'Sheet1 (126)', 'Sheet1 (127)', 'Sheet1 (128)', 'Sheet1 (33)', 'Sheet1 (34)', 'Sheet1 (35)', 'Sheet1 (36)', 'Sheet1 (37)', 'Sheet1 (38)', 'Sheet1 (39)', 'Sheet1 (40)', 'Sheet1 (41)', 'Sheet1 (42)', 'Sheet1 (43)', 'Sheet1 (44)', 'Sheet1 (45)', 'Sheet1 (46)', 'Sheet1 (47)', 'Sheet1 (48)', 'Sheet1 (49)', 'Sheet1 (50)', 'Sheet1 (51)', 'Sheet1 (52)', 'Sheet1 (53)', 'Sheet1 (54)', 'Sheet1 (55)', 'Sheet1 (56)', 'Sheet1 (57)', 'Sheet1 (58)', 'Sheet1 (59)', 'Sheet1 (60)', 'Sheet1 (61)', 'Sheet1 (62)', 'Sheet1 (63)', 'Sheet1 (64)', 'Sheet1 (17)', 'Sheet1 (18)', 'Sheet1 (19)', 'Sheet1 (20)', 'Sheet1 (21)', 'Sheet1 (22)', 'Sheet1 (23)', 'Sheet1 (24)', 'Sheet1 (25)', 'Sheet1 (26)', 'Sheet1 (27)', 'Sheet1 (28)', 'Sheet1 (29)', 'Sheet1 (30)', 'Sheet1 (31)', 'Sheet1 (32)', 'Sheet1 (9)', 'Sheet1 (10)', 'Sheet1 (11)', 'Sheet1 (12)', 'Sheet1 (13)', 'Sheet1 (14)', 'Sheet1 (15)', 'Sheet1 (16)', 'Sheet1 (5)', 'Sheet1 (6)', 'Sheet1 (7)', 'Sheet1 (8)', 'Sheet1 (3)', 'Sheet1 (4)', 'Sheet1 (2)', 'Sheet ...
# text:'Công ty TNHH TM & DV Ôtô Trí Minh' (XF:84) text:'Lô B11-01, Lê Quý Đôn, Tp Tam Kỳ, tỉnh Quảng Nam' (XF:85) text:'Nguyễn T Thái Thanh' (XF:69) blank:'' (XF:69) text:'Nguyễn T Thái Thanh' (XF:69) text:'Huỳnh Văn Phát' (XF:69)

# %% [markdown]
# ## Lọc theo tháng

# %%
rows = {}
rows_by_month = {}
for i in range (0, qt.nrows): 
    # Check if this row is UNVALID
    if isinstance (qt.cell(i,0).value, str):
        continue
    date = xlrd.xldate_as_datetime(qt.cell(i, 1).value, datemode = 0)

    phieuId = ''
    # Check for safety if both [phieuThuID] and [phieuChiID] is blank
    if (qt.cell(i,2).value == '' and qt.cell(i,3).value != ''):
        phieuId = qt.cell(i,3).value
    elif (qt.cell(i,2).value != '' and qt.cell(i,3).value == ''):
        phieuId = qt.cell(i,2).value
    
    tienThu = 0
    # Check for safety if both [tienThu] and [tienChi] is blank (convert to zero) or zero
    if isinstance(qt.cell(i,9).value, str):
        if (qt.cell(i,9) == ''):
            tienThu = 0
        else:
            tienThu = int(qt.cell(i,9))
    if isinstance(qt.cell(i,11).value, str):
        if (qt.cell(i,11) == ''):
            tienThu = 0
        else:
            tienThu = int(qt.cell(i,11))

    # If phieuID is available in list [rows.keys()]
    if phieuId in rows.keys(): 
        rows[phieuId]['tien'] += (qt.cell(i,9).value +  qt.cell(i,11).value)
        if qt.cell(i,8).value not in rows[phieuId]['tk']:
            rows[phieuId]['tk'] += (',' + qt.cell(i,8).value)
    else:
        rows[phieuId] = {
            'date'  :   date,
            'lyDo'  :   qt.cell(i,6).value,
            'tk'    :   qt.cell(i,8).value,
            'tien'  :   qt.cell(i,9).value +  qt.cell(i,11).value,
            'kemTheo':   qt.cell(i,15).value,
            'hoTen' :   qt.cell(i,16).value,
            'diaChi':   qt.cell(i,17).value,
            'loai'  :   'phieuChi' if (qt.cell(i,2).value == '') else 'phieuThu'
        }
        
    # Check for the [nextDate] is next month or no valid ('')
    if isinstance(qt.cell(i + 1, 1).value, float):
        nextDate    = xlrd.xldate_as_datetime(qt.cell(i + 1, 1).value, datemode = 0) 
    else:
        nextDate = '' 
    if (nextDate != '') and (date.month != nextDate.month):
        rows_by_month[f'{date.month}-{date.year}'] = rows  # Add [rows] to [rows_by_month]
        rows = {} # Empty [rows]
rows_by_month[f'{date.month}-{date.year}'] = rows  # Add [rows] to [rows_by_month]
rows_by_month.keys()
print('50%')
# Out:
# 0
# 1
# 2
# 3
# 4
# 1->2PC-00012->PC-00001
# 2->3PC-00007->DTDV-00004
# 3->4PC-00006->DTDV-00003
# 4->5PC-00006->GBNO-00001
# 5->6GBCO-00017->PC-00001
# 6->7PC-00009->GBNO-00001
# 7->8PC-00011->PC-00001
# 8->9PC-00009->GBNO-00001
# 9->10PC-00011->DTDV-00001
# 10->11PC-00013->GBNO-00001
# 11->12PC-00011->GBNO-00001
# 766
# 767
# {'1-2018': {'GBNO-00001': {'date': datetime.datetime(2018, 1, 2, 0, 0),
#    'lyDo': 'rút tiền nhập quỹ',
#    'tk': '1121',
#    'tien': 0.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00002': {'date': datetime.datetime(2018, 1, 2, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 3000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00001': {'date': datetime.datetime(2018, 1, 2, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ337124,312914',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ337124,312914',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBNO-00003': {'date': datetime.datetime(2018, 1, 8, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 70000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00002': {'date': datetime.datetime(2018, 1, 10, 0, 0),
#    'lyDo': 'Trả tiền mua hàng ',
#    'tk': '331',
#    'tien': 8166400.0,
#    'kemTheo': '',
#    'hoTen': 'Công ty TNHH MTV Kim Hoàng Hải',
#    'diaChi': '32, Lê Ngọc Hân, P.Hòa Hương, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PT-00001': {'date': datetime.datetime(2018, 1, 15, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 43C-10796,92A-051.00,92A-005.45',
#    'tk': '131',
#    'tien': 12358500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00001': {'date': datetime.datetime(2018, 1, 16, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ00449',
#    'tk': '152,1331',
#    'tien': 11189000.0,
#    'kemTheo': 'HĐ00449',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'NNVL-00003': {'date': datetime.datetime(2018, 1, 18, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ00196',
#    'tk': '152,1331',
#    'tien': 0.0,
#    'kemTheo': 'HĐ00196',
#    'hoTen': 'Chi nhánh Công ty CP Dầu nhớt Tiến Thành',
#    'diaChi': '133 Tôn Đức Thắng, P. Hòa An, Q.Caame Lệ, Tp Đà Nẵng',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 1, 19, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ826787',
#    'tk': '6422,1331',
#    'tien': 0.0,
#    'kemTheo': 'HĐ826787',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 1, 19, 0, 0),
#    'lyDo': 'trả tiền mua vật tư HĐ5688',
#    'tk': '1547,1331',
#    'tien': 0.0,
#    'kemTheo': 'HĐ5688',
#    'hoTen': 'CN Cty TNHH T.Tâm Dịch Total Viêt Nam Tại Quảng Nam',
#    'diaChi': 'Giao Lô Nguyễn Hoàng, Phan Bội Châu, P. Hòa Thuận, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 1, 19, 0, 0),
#    'lyDo': 'Trả tiền mua hàng ',
#    'tk': '331',
#    'tien': 0.0,
#    'kemTheo': '',
#    'hoTen': 'Cửa hàng phụ tùng Nga',
#    'diaChi': '500, Phan Chu Trinh, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PT-00002': {'date': datetime.datetime(2018, 1, 20, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-4753',
#    'tk': '131',
#    'tien': 0.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00004': {'date': datetime.datetime(2018, 1, 20, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ00044',
#    'tk': '152,152,1331',
#    'tien': 0.0,
#    'kemTheo': 'HĐ00044',
#    'hoTen': 'Công ty TNHH V.T.H Quảng Nam',
#    'diaChi': '124 Lý Thường Kiệt, P.An Mỹ, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 1, 22, 0, 0),
#    'lyDo': 'Trả tiền mua hàng ',
#    'tk': '331',
#    'tien': 14000000.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH MTV Long Minh Ánh',
#    'diaChi': '07 Cô Bắc, P. Hải châu II, Q. Hải Châu, Tp Đà Nẵng',
#    'loai': 'phieuChi'},
#   'PT-00003': {'date': datetime.datetime(2018, 1, 25, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-067.45,92M-000.16',
#    'tk': '131',
#    'tien': 7700000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 1, 25, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-078.17',
#    'tk': '131',
#    'tien': 2000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00012': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2670',
#    'tk': '152,152,1331',
#    'tien': 8910000.0,
#    'kemTheo': 'HĐ2670',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '31, Huỳnh Thúc Kháng, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'trả tiền sạc mực máy in HĐ00334',
#    'tk': '6422,1331',
#    'tien': 200000.0,
#    'kemTheo': 'HĐ00334',
#    'hoTen': 'Cty TNHH MTV TM&DV Đức Hào Quảng Nam',
#    'diaChi': '160 Phan Châu Trinh, Tp Tam kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'trả tiền nước sinh hoạt HĐ014524',
#    'tk': '6422,1331',
#    'tien': 249896.0,
#    'kemTheo': 'HĐ014524',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00009': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'chi trả tiền mua bình nóng lạnh HĐ2453',
#    'tk': '153,1331',
#    'tien': 7500000.0,
#    'kemTheo': 'HĐ2453',
#    'hoTen': 'DNTN Thương mại & DV Tân Nhật Thanh',
#    'diaChi': '477, Phan Chu Trinh, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PC-00010': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'Trả tiền mua hàng ',
#    'tk': '331',
#    'tien': 15000000.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH MTV Quang Phương Minh',
#    'diaChi': 'Lô 1 Nguyễn Hoàng, KP 4, An Xuân,, Tam kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00011': {'date': datetime.datetime(2018, 1, 30, 0, 0),
#    'lyDo': 'Trả tiền mua hàng ',
#    'tk': '331',
#    'tien': 10001645.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH Khánh Trường Sinh',
#    'diaChi': '69 Phan Bội Châu, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PT-00005': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe ',
#    'tk': '131',
#    'tien': 1488000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 93E-0609,92E-1022,92A-003.72,92E-0762,92M-000.02,92E-1022',
#    'tk': '131',
#    'tien': 14100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00007': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-5944',
#    'tk': '131',
#    'tien': 7975000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00008': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-5377',
#    'tk': '131',
#    'tien': 9526000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00009': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92C-105.94',
#    'tk': '131',
#    'tien': 9680000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00010': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-3535',
#    'tk': '131',
#    'tien': 7939800.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00011': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92K-2836',
#    'tk': '131',
#    'tien': 19734000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00012': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-2379,VT-2376,VT-1285',
#    'tk': '131',
#    'tien': 2992000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00013': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-2374,VT-2380,VT-2165,VT-2080,VT-2523',
#    'tk': '131',
#    'tien': 1330000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00014': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92K-6667',
#    'tk': '131',
#    'tien': 3938000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00015': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92C-047.12,92A-023.51,92C-047.12',
#    'tk': '131',
#    'tien': 12540000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00016': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92H-0572',
#    'tk': '131',
#    'tien': 9372000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00017': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92C-108.08',
#    'tk': '131',
#    'tien': 5863000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00018': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92E-0729,92A-002.98',
#    'tk': '131',
#    'tien': 3465000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00012': {'date': datetime.datetime(2018, 1, 31, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 01/2018',
#    'tk': '334',
#    'tien': 42400000.0,
#    'kemTheo': 'BKLuong T01/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '2-2018': {'PC-00001': {'date': datetime.datetime(2018, 2, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ416261,432069',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ416261,432069',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBCO-00003': {'date': datetime.datetime(2018, 2, 6, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 2000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'VT-00001': {'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'lyDo': 'Nhận nợ vốn vay ',
#    'tk': '3411',
#    'tien': 95000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00001': {'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ00548',
#    'tk': '152,152,152,1331',
#    'tien': 14245000.0,
#    'kemTheo': 'HĐ00548',
#    'hoTen': 'Cty TNHH MTV Đỗ Nhật',
#    'diaChi': 'Lô D47, đường N10, P.Hòa Thuận, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'GBNO-00004': {'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 100000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00005': {'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 40000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00002': {'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'lyDo': 'Trả tiền mua hàng',
#    'tk': '331',
#    'tien': 9000000.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH MTV Long Minh Ánh',
#    'diaChi': '07 Cô Bắc, P. Hải châu II, Q. Hải Châu, Tp Đà Nẵng',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'lyDo': 'Trả tiền mua hàng',
#    'tk': '331',
#    'tien': 14369505.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH MTV Quang Phương Minh',
#    'diaChi': 'Lô 1 Nguyễn Hoàng, KP 4, An Xuân,, Tam kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBNO-00007': {'date': datetime.datetime(2018, 2, 12, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 15000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00004': {'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ832302',
#    'tk': '6422,1331',
#    'tien': 273000.0,
#    'kemTheo': 'HĐ832302',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ062089',
#    'tk': '6422,1331',
#    'tien': 218659.0,
#    'kemTheo': 'HĐ062089',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'NNVL-00003': {'date': datetime.datetime(2018, 2, 23, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ14168',
#    'tk': '152,152,1331',
#    'tien': 3580000.0,
#    'kemTheo': 'HĐ14168',
#    'hoTen': 'Công ty TNHH Trí Hoàng',
#    'diaChi': '202, Phan Chu Trinh, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PT-00001': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92A-020.97,92A-003.72,92A-034.19',
#    'tk': '131',
#    'tien': 5200000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-1399',
#    'tk': '131',
#    'tien': 495000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00003': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92C-026.17',
#    'tk': '131',
#    'tien': 5170000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-2381,VT-2378,VT-2380,VT-2374,VT-2165,VT-2124',
#    'tk': '131',
#    'tien': 4835000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00005': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92K-5455',
#    'tk': '131',
#    'tien': 3520000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92H-0572',
#    'tk': '131',
#    'tien': 3707000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00007': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92H-0440',
#    'tk': '131',
#    'tien': 9960500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00008': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92A-002.98',
#    'tk': '131',
#    'tien': 4840000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00006': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ02678',
#    'tk': '152,152,152,1331',
#    'tien': 7750000.0,
#    'kemTheo': 'HĐ02678',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '31, Huỳnh Thúc Kháng, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'trả phí môi trường HĐ05685',
#    'tk': '6422,1331',
#    'tien': 660000.0,
#    'kemTheo': 'HĐ05685',
#    'hoTen': 'C.ty TNHH MTV Môi trường đô thị Q.Nam',
#    'diaChi': '781, Phan Chu Trinh, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 02/2018',
#    'tk': '334',
#    'tien': 40600000.0,
#    'kemTheo': 'BKLuong T02/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '3-2018': {'DTDV-00004': {'date': datetime.datetime(2018, 3, 2, 0, 0),
#    'lyDo': 'Sửa chữa xe 92A-012.48',
#    'tk': '5113,33311',
#    'tien': 544500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00005': {'date': datetime.datetime(2018, 3, 2, 0, 0),
#    'lyDo': 'Sửa chữa xe 51F-551.92',
#    'tk': '5113,33311',
#    'tien': 929500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00001': {'date': datetime.datetime(2018, 3, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ493542,446731',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ493542,446731',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00002': {'date': datetime.datetime(2018, 3, 5, 0, 0),
#    'lyDo': 'Trả tiền mua giấy  HĐ32789',
#    'tk': '6422,1331',
#    'tien': 1145000.0,
#    'kemTheo': 'HĐ32789',
#    'hoTen': 'DNTN Nghĩa Lợi',
#    'diaChi': '451 - 453 Hùng Vương, P. An Sơn, TP Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBCO-00001': {'date': datetime.datetime(2018, 3, 6, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 3000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'DTDV-00018': {'date': datetime.datetime(2018, 3, 13, 0, 0),
#    'lyDo': 'Sửa chữa xe 92E-0729',
#    'tk': '5113,33311',
#    'tien': 990000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00022': {'date': datetime.datetime(2018, 3, 19, 0, 0),
#    'lyDo': 'Sửa chữa xe 92A-005.46',
#    'tk': '5113,33311',
#    'tien': 990000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00002': {'date': datetime.datetime(2018, 3, 22, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2689',
#    'tk': '152,152,152,1331',
#    'tien': 4450000.0,
#    'kemTheo': 'HĐ2689',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '31, Huỳnh Thúc Kháng, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 3, 23, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ836577',
#    'tk': '6422,1331',
#    'tien': 230800.0,
#    'kemTheo': 'HĐ836577',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 3, 23, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư HĐ06862',
#    'tk': '1547,1331',
#    'tien': 5610000.0,
#    'kemTheo': 'HĐ06862',
#    'hoTen': 'CN Cty TNHH T.Tâm Dịch Total Viêt Nam Tại Quảng Nam',
#    'diaChi': 'Giao Lô Nguyễn Hoàng, Phan Bội Châu, P. Hòa Thuận, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBNO-00010': {'date': datetime.datetime(2018, 3, 30, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 20000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00014': {'date': datetime.datetime(2018, 3, 30, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 1200000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PT-00001': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92A-040.78',
#    'tk': '131',
#    'tien': 1650000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 43H-5556,43A-047.48,92A-102.07',
#    'tk': '131',
#    'tien': 8855000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00003': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-2379,VT-2248,VT-2376,VT-1285',
#    'tk': '131',
#    'tien': 3685000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe VT-2571,VT-2374,VT-2375,VT-1353,VT-2165',
#    'tk': '131',
#    'tien': 2625000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00005': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92K-5377,92K-6667',
#    'tk': '131',
#    'tien': 8800000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92A-067.95',
#    'tk': '131',
#    'tien': 1540000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00007': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'thu tiền sửa xe 92K-8474',
#    'tk': '131',
#    'tien': 9460000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00005': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ0118930',
#    'tk': '6422,1331',
#    'tien': 104124.0,
#    'kemTheo': 'HĐ0118930',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 3/2018',
#    'tk': '334',
#    'tien': 32357000.0,
#    'kemTheo': 'BKLuong T03/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '4-2018': {'DTDV-00003': {'date': datetime.datetime(2018, 4, 4, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-2836',
#    'tk': '5113,33311',
#    'tien': 396000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00001': {'date': datetime.datetime(2018, 4, 4, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ541008,611902',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ541008,611902',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00002': {'date': datetime.datetime(2018, 4, 4, 0, 0),
#    'lyDo': 'Thanh toán tiền mua nước uống HĐ00435',
#    'tk': '6422,1331',
#    'tien': 1110000.0,
#    'kemTheo': 'HĐ00435',
#    'hoTen': 'Cty TNHH TM&DV Trần Lưu',
#    'diaChi': 'Đường Thanh Hóa, P. An Sơn, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'DTDV-00004': {'date': datetime.datetime(2018, 4, 7, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-2089',
#    'tk': '5113,33311',
#    'tien': 770000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00027': {'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'lyDo': 'Sửa chữa xe 92A-071.68 & 92A-110.08',
#    'tk': '5113,33311',
#    'tien': 2200000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00004': {'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 16000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00001': {'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92C-051.39',
#    'tk': '131',
#    'tien': 9702000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00005': {'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'lyDo': 'nộp tiền vào tài khoản',
#    'tk': '1121',
#    'tien': 29978000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ969279',
#    'tk': '6422,1331',
#    'tien': 625583.0,
#    'kemTheo': 'HĐ969279',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'NNVL-00008': {'date': datetime.datetime(2018, 4, 26, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0542',
#    'tk': '152,152,152,152,152,152,152,152,1331',
#    'tien': 15401100.0,
#    'kemTheo': 'HĐ0542',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'NNVL-00009': {'date': datetime.datetime(2018, 4, 28, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0555',
#    'tk': '152,152,152,152,152,152,152,152,1331',
#    'tien': 12948100.0,
#    'kemTheo': 'HĐ0555',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 4, 28, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ169817',
#    'tk': '6422,1331',
#    'tien': 156185.0,
#    'kemTheo': 'HĐ169817',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 4, 28, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư HĐ0513',
#    'tk': '1547,1331',
#    'tien': 6386220.0,
#    'kemTheo': 'HĐ0513',
#    'hoTen': 'CN Cty TNHH T.Tâm Dịch Total Viêt Nam Tại Quảng Nam',
#    'diaChi': 'Giao Lô Nguyễn Hoàng, Phan Bội Châu, P. Hòa Thuận, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PT-00002': {'date': datetime.datetime(2018, 4, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-00.21',
#    'tk': '131',
#    'tien': 2970000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00003': {'date': datetime.datetime(2018, 4, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-2379;VT-1285',
#    'tk': '131',
#    'tien': 4070000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 4, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-2212,VT-2380,VT-2080',
#    'tk': '131',
#    'tien': 810000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00005': {'date': datetime.datetime(2018, 4, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-001.26,92K-2023',
#    'tk': '131',
#    'tien': 10340000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 4, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-3202',
#    'tk': '131',
#    'tien': 14619000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00006': {'date': datetime.datetime(2018, 4, 30, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 4/2018',
#    'tk': '334',
#    'tien': 30818000.0,
#    'kemTheo': 'bKLuong T04/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '5-2018': {'GBNO-00001': {'date': datetime.datetime(2018, 5, 2, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 20000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00002': {'date': datetime.datetime(2018, 5, 4, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 3000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00001': {'date': datetime.datetime(2018, 5, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ721542,706579',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ721542,706579',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'DTDV-00015': {'date': datetime.datetime(2018, 5, 10, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-8458',
#    'tk': '5113,33311',
#    'tien': 9977000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00001': {'date': datetime.datetime(2018, 5, 11, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ61562',
#    'tk': '152',
#    'tien': 6800000.0,
#    'kemTheo': 'HĐ61562',
#    'hoTen': 'Kính Ô tô Hồng Hải (Mai Thị Hạnh Nguyên)',
#    'diaChi': '244, Điện Biên Phủ, P. Chính Gián, Q. Thanh Khê, Tp Đà Nẵng',
#    'loai': 'phieuChi'},
#   'DTDV-00026': {'date': datetime.datetime(2018, 5, 14, 0, 0),
#    'lyDo': 'Sửa chữa xe 92A-005.46',
#    'tk': '5113,33311',
#    'tien': 1045000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00003': {'date': datetime.datetime(2018, 5, 14, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00004': {'date': datetime.datetime(2018, 5, 16, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 6000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00002': {'date': datetime.datetime(2018, 5, 19, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ215690',
#    'tk': '6422,1331',
#    'tien': 104000.0,
#    'kemTheo': 'HĐ215690',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 5, 19, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ43839',
#    'tk': '6422,1331',
#    'tien': 190000.0,
#    'kemTheo': 'HĐ43839',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'PT-00001': {'date': datetime.datetime(2018, 5, 20, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-2374',
#    'tk': '131',
#    'tien': 10626000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 5, 20, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 57M-3437',
#    'tk': '131',
#    'tien': 8624000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00006': {'date': datetime.datetime(2018, 5, 26, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2733 ',
#    'tk': '152,1331',
#    'tien': 6550000.0,
#    'kemTheo': 'HĐ2733',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '31, Huỳnh Thúc Kháng, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 5, 26, 0, 0),
#    'lyDo': 'Trả tiền gia công cơ khí HĐ00376',
#    'tk': '1543,1331',
#    'tien': 15400000.0,
#    'kemTheo': 'HĐ00376',
#    'hoTen': 'DNTN Nam Định',
#    'diaChi': '61,63 Đỗ Quang, Q.Thanh Khê, TP Đà Nẵng',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 5, 26, 0, 0),
#    'lyDo': 'Trả phí môi trường HĐ01765',
#    'tk': '6422,1331',
#    'tien': 660000.0,
#    'kemTheo': 'HĐ01765',
#    'hoTen': 'C.ty TNHH MTV Môi trường đô thị Q.Nam',
#    'diaChi': '781, Phan Chu Trinh, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 5, 26, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư thép HĐ1108',
#    'tk': '6422,1331',
#    'tien': 7006472.0,
#    'kemTheo': 'HĐ1108',
#    'hoTen': 'Cty TNHH Khánh Trường Sinh',
#    'diaChi': '69 Phan Bội Châu, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBNO-00010': {'date': datetime.datetime(2018, 5, 28, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00011': {'date': datetime.datetime(2018, 5, 29, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 2000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00007': {'date': datetime.datetime(2018, 5, 29, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0572',
#    'tk': '152,152,152,152,152,152,152,1331',
#    'tien': 15232800.0,
#    'kemTheo': 'HĐ0572',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 5, 29, 0, 0),
#    'lyDo': 'Trả tiền tiếp khách HĐ10234',
#    'tk': '6422,1331',
#    'tien': 2646000.0,
#    'kemTheo': 'HĐ10234',
#    'hoTen': 'Công ty TNHH MTV Thủy Hoàng Huy',
#    'diaChi': 'Lô B1, KCD Bạch Đằng, P. Phước Hòa, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 5, 30, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 5/2018',
#    'tk': '334',
#    'tien': 36400000.0,
#    'kemTheo': 'bKLuong T5/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'},
#   'PT-00003': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-090.80',
#    'tk': '131',
#    'tien': 6160000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-098.37',
#    'tk': '131',
#    'tien': 3927000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00005': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92C-074.20',
#    'tk': '131',
#    'tien': 15576000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe Viettel Q.Nam - CN Tập đoàn VT Quân đội',
#    'tk': '131',
#    'tien': 4642000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00007': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe Công ty cổ phần công trình Viettel',
#    'tk': '131',
#    'tien': 7213000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00008': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe92K-5711,92K-5377',
#    'tk': '131',
#    'tien': 8162000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00009': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 57M-3437',
#    'tk': '131',
#    'tien': 5060000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00017': {'date': datetime.datetime(2018, 5, 31, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 3500000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'}},
#  '6-2018': {'PC-00001': {'date': datetime.datetime(2018, 6, 4, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ752602,796123',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ752602,796123',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00002': {'date': datetime.datetime(2018, 6, 6, 0, 0),
#    'lyDo': 'Trả tiền mua công cụ, dụng cụ HĐ0592',
#    'tk': '153,153,153,153,153,153,153,1331',
#    'tien': 9168500.0,
#    'kemTheo': 'HĐ0592',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'GBNO-00001': {'date': datetime.datetime(2018, 6, 8, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 4000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00003': {'date': datetime.datetime(2018, 6, 12, 0, 0),
#    'lyDo': 'giảm nợ vốn vay ',
#    'tk': '3411',
#    'tien': 95000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 6, 12, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ43995',
#    'tk': '6422,1331',
#    'tien': 200000.0,
#    'kemTheo': 'HĐ43995',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'NNVL-00004': {'date': datetime.datetime(2018, 6, 13, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0131',
#    'tk': '152,152,152,1331',
#    'tien': 5300000.0,
#    'kemTheo': 'HĐ0131',
#    'hoTen': 'DNTN Ngọc Nhật',
#    'diaChi': '74, Phan Chu Trinh, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 6, 14, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư HĐ01461',
#    'tk': '1547,1331',
#    'tien': 6570000.0,
#    'kemTheo': 'HĐ01461',
#    'hoTen': 'CN Cty TNHH T.Tâm Dịch Total Viêt Nam Tại Quảng Nam',
#    'diaChi': 'Giao Lô Nguyễn Hoàng, Phan Bội Châu, P. Hòa Thuận, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBCO-00003': {'date': datetime.datetime(2018, 6, 15, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 12000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'NNVL-00005': {'date': datetime.datetime(2018, 6, 15, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0598',
#    'tk': '152,152,152,152,152,1331',
#    'tien': 9126700.0,
#    'kemTheo': 'HĐ0598',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 6, 19, 0, 0),
#    'lyDo': 'Trả tiền mua máy casio, phí rác HĐ10849+763+764+765',
#    'tk': '6422,1331',
#    'tien': 560000.0,
#    'kemTheo': 'HĐ10849+763+764+765',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 6, 19, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ267143',
#    'tk': '6422,1331',
#    'tien': 166598.0,
#    'kemTheo': 'HĐ267143',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 6, 19, 0, 0),
#    'lyDo': 'Nộp lãi vốn vay',
#    'tk': '635',
#    'tien': 320137.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'DTDV-00017': {'date': datetime.datetime(2018, 6, 20, 0, 0),
#    'lyDo': 'Sửa chữa xe 51F-551.92',
#    'tk': '5113,33311',
#    'tien': 665500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00007': {'date': datetime.datetime(2018, 6, 20, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0005',
#    'tk': '152,152,1331',
#    'tien': 6160000.0,
#    'kemTheo': 'HĐ0005',
#    'hoTen': 'Công ty TNHH TMDV Tâm Tâm Anh',
#    'diaChi': '140A Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'NNVL-00008': {'date': datetime.datetime(2018, 6, 21, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0601',
#    'tk': '152,152,152,152,152,152,152,152,152,152,1331',
#    'tien': 16195300.0,
#    'kemTheo': 'HĐ0601',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'NNVL-00010': {'date': datetime.datetime(2018, 6, 25, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2745',
#    'tk': '152,152,152,1331',
#    'tien': 7550000.0,
#    'kemTheo': 'HĐ2745',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '31, Huỳnh Thúc Kháng, Tam Kỳ',
#    'loai': 'phieuChi'},
#   'DTDV-00036': {'date': datetime.datetime(2018, 6, 27, 0, 0),
#    'lyDo': 'Sửa chữa xe 80B-5817',
#    'tk': '5113,33311',
#    'tien': 1595000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00010': {'date': datetime.datetime(2018, 6, 27, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 16000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00011': {'date': datetime.datetime(2018, 6, 27, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 45000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00001': {'date': datetime.datetime(2018, 6, 28, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-2375',
#    'tk': '131',
#    'tien': 7315000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 6, 29, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-2080,VT-2165',
#    'tk': '131',
#    'tien': 10494000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00014': {'date': datetime.datetime(2018, 6, 29, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 4000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PT-00003': {'date': datetime.datetime(2018, 6, 30, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-005.45',
#    'tk': '131',
#    'tien': 3355000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 6, 30, 0, 0),
#    'lyDo': 'Thu tiền sửa xe Công ty cổ phần công trình Viettel',
#    'tk': '131',
#    'tien': 8444000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00005': {'date': datetime.datetime(2018, 6, 30, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 30A-376.85 HĐ 721&749',
#    'tk': '131',
#    'tien': 6798000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00006': {'date': datetime.datetime(2018, 6, 30, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-3535',
#    'tk': '131',
#    'tien': 14011800.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00009': {'date': datetime.datetime(2018, 6, 30, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 6/2018',
#    'tk': '334',
#    'tien': 36400000.0,
#    'kemTheo': 'BKLuong T6/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '7-2018': {'GBNO-00001': {'date': datetime.datetime(2018, 7, 1, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00002': {'date': datetime.datetime(2018, 7, 2, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00006': {'date': datetime.datetime(2018, 7, 4, 0, 0),
#    'lyDo': 'Sửa chữa xe 86A-006.78',
#    'tk': '5113,33311',
#    'tien': 7480000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00001': {'date': datetime.datetime(2018, 7, 5, 0, 0),
#    'lyDo': 'Thanh toán tiền mua nước uống HĐ1067',
#    'tk': '6422,1331',
#    'tien': 962000.0,
#    'kemTheo': 'HĐ1067',
#    'hoTen': 'Cty TNHH TM&DV Trần Lưu',
#    'diaChi': 'Đường Thanh Hóa, P. An Sơn, Tp Tam Kỳ, tỉnh Quảng Nam',
#    'loai': 'phieuChi'},
#   'PC-00002': {'date': datetime.datetime(2018, 7, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ0858314,0901570',
#    'tk': '6422,1331',
#    'tien': 187000.0,
#    'kemTheo': 'HĐ0858314,0901570',
#    'hoTen': 'Trung tâm KD VNPT- QNAm - CN Tổng Cty Dịch vụ Viễn Thông',
#    'diaChi': '02 Phan Bội Châu, P. Tân Thạnh, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 7, 5, 0, 0),
#    'lyDo': 'Trả tiền mua giấy HĐ 37067',
#    'tk': '6422,1331',
#    'tien': 1500000.0,
#    'kemTheo': 'HĐ 37067',
#    'hoTen': 'DNTN Nghĩa Lợi',
#    'diaChi': '451 - 453 Hùng Vương, P. An Sơn, TP Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'GBNO-00004': {'date': datetime.datetime(2018, 7, 9, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 40000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00004': {'date': datetime.datetime(2018, 7, 9, 0, 0),
#    'lyDo': 'Giảm nợ vốn vay+ trả lãi vay',
#    'tk': '3411',
#    'tien': 95277453.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 7, 9, 0, 0),
#    'lyDo': 'Thanh toán tiền mua vật tư HĐ01690',
#    'tk': '1547,1331',
#    'tien': 5000000.0,
#    'kemTheo': 'HĐ01690',
#    'hoTen': 'CN Cty TNHH T.Tâm Dịch Total Viêt Nam Tại Quảng Nam',
#    'diaChi': 'Giao Lô Nguyễn Hoàng, Phan Bội Châu, P. Hòa Thuận, Tp Tam Kỳ, Qnam',
#    'loai': 'phieuChi'},
#   'NNVL-00002': {'date': datetime.datetime(2018, 7, 16, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0186',
#    'tk': '152,152,152,152,152,152,152,152,152,1331',
#    'tien': 2746700.0,
#    'kemTheo': 'HĐ0186',
#    'hoTen': 'C.ty cp đầu tư công nghệ Đại Mỹ',
#    'diaChi': '86, đường 2/9,Q.Hải Châu, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 7, 18, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ50556',
#    'tk': '6422,1331',
#    'tien': 220000.0,
#    'kemTheo': 'HĐ50556',
#    'hoTen': 'Công ty DV Viễn thông Mobifone KV3',
#    'diaChi': '263, Nguyễn Văn Linh, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 7, 18, 0, 0),
#    'lyDo': 'trả tiền nước sinh hoạt HĐ0318960',
#    'tk': '6422,1331',
#    'tien': 187422.0,
#    'kemTheo': 'HĐ0318960',
#    'hoTen': 'Cty CP Cấp Thoát Nước Quảng Nam',
#    'diaChi': 'Điện Biên Phủ, Tam Kỳ, QNam',
#    'loai': 'phieuChi'},
#   'DTDV-00026': {'date': datetime.datetime(2018, 7, 24, 0, 0),
#    'lyDo': 'Sửa chữa xe 57M-3437',
#    'tk': '5113,33311',
#    'tien': 660000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00004': {'date': datetime.datetime(2018, 7, 24, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2760',
#    'tk': '152,1331',
#    'tien': 3780000.0,
#    'kemTheo': 'HĐ2760',
#    'hoTen': 'DN TN Thạch Thông',
#    'diaChi': '31 Huỳnh Thúc Kháng-Tam Kỳ',
#    'loai': 'phieuChi'},
#   'NNVL-00007': {'date': datetime.datetime(2018, 7, 25, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ50733',
#    'tk': '152',
#    'tien': 4800000.0,
#    'kemTheo': 'HĐ50733',
#    'hoTen': 'Vũ Thành Trung',
#    'diaChi': 'Tổ 6, khối phố 5-P.An Xuân -Tam Kỳ',
#    'loai': 'phieuChi'},
#   'NNVL-00008': {'date': datetime.datetime(2018, 7, 26, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ2761',
#    'tk': '152,152,1331',
#    'tien': 4225000.0,
#    'kemTheo': 'HĐ2761',
#    'hoTen': 'DNTN Thạch Thông',
#    'diaChi': '32 Huỳnh Thúc Kháng-Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 7, 26, 0, 0),
#    'lyDo': 'Trả tiền mua chất tẩy rửa HĐ16747',
#    'tk': '6422,1331',
#    'tien': 4545000.0,
#    'kemTheo': 'HĐ16747',
#    'hoTen': 'CTTNHH Thiên Hương',
#    'diaChi': '378 Phạm Văn Đồng - Tam Kỳ',
#    'loai': 'phieuChi'},
#   'PC-00009': {'date': datetime.datetime(2018, 7, 26, 0, 0),
#    'lyDo': 'Trả tiền mua Keyboard+ sửa máy VT HĐ5791,5789',
#    'tk': '6422,1331',
#    'tien': 580000.0,
#    'kemTheo': 'HĐ5791,5789',
#    'hoTen': 'CN Cty TNHH CN Quốc Nghĩa',
#    'diaChi': 'Tầng trệt Sthi CoopMart Tam Kỳ, P. Phước Hòa, QNam  ',
#    'loai': 'phieuChi'},
#   'DTDV-00028': {'date': datetime.datetime(2018, 7, 27, 0, 0),
#    'lyDo': 'Sửa chữa xe 92E-0729',
#    'tk': '5113,33311',
#    'tien': 990000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00010': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 100000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00001': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-034.19,92A-001.25,37A-150.09',
#    'tk': '131',
#    'tien': 10202000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92K-5535',
#    'tk': '131',
#    'tien': 15785000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00003': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe Viettel Q.Nam - CN Tập đoàn VT Quân đội',
#    'tk': '131',
#    'tien': 6908000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00004': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Thu tiền sửa xe VT-8485',
#    'tk': '131',
#    'tien': 10428000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00013': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 84000000.0,
#    'kemTheo': '',
#    'hoTen': 'Huỳnh Văn Phát',
#    'diaChi': 'Giám đốc',
#    'loai': 'phieuChi'},
#   'NNVL-00010': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ0653',
#    'tk': '152,152,152,152,152,152,152,152,152,152,152,152,1331',
#    'tien': 18691200.0,
#    'kemTheo': 'HĐ0653',
#    'hoTen': 'CN C.ty cp phụ tùng và tư vấn ô tô',
#    'diaChi': '106, Điện Biên Phủ, ĐN',
#    'loai': 'phieuChi'},
#   'PC-00010': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư phụ tùng ',
#    'tk': '331',
#    'tien': 5289409.0,
#    'kemTheo': '',
#    'hoTen': 'Cty TNHH Hiệp Vĩnh An',
#    'diaChi': 'Tổ 7, P. Hòa An, Q. Cẩm Lệ, TP Đà Nẵng, VN',
#    'loai': 'phieuChi'},
#   'PC-00011': {'date': datetime.datetime(2018, 7, 31, 0, 0),
#    'lyDo': 'Thanh toán tiền lương tháng 7/2018',
#    'tk': '334',
#    'tien': 35428000.0,
#    'kemTheo': 'BKLuong T7/2018',
#    'hoTen': 'Lê Minh Trọng',
#    'diaChi': 'Công nhân',
#    'loai': 'phieuChi'}},
#  '8-2018': {'PC-00001': {'date': datetime.datetime(2018, 8, 3, 0, 0),
#    'lyDo': 'Giảm nợ vốn vay',
#    'tk': '3411',
#    'tien': 50000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'NNVL-00001': {'date': datetime.datetime(2018, 8, 4, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0668',
#    'tk': '152,1331',
#    'tien': 12314500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'NNVL-00003': {'date': datetime.datetime(2018, 8, 6, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0018',
# ...
#    'lyDo': 'Sửa chữa xe 92M-00114',
#    'tk': '5113,33311',
#    'tien': 396000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00001': {'date': datetime.datetime(2018, 10, 5, 0, 0),
#    'lyDo': 'Trả tiền mua Gói VBH 1 năm-KHVT-CA HĐ 0462251',
#    'tk': '6422',
#    'tien': 479000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00002': {'date': datetime.datetime(2018, 10, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ 0191406,0253069',
#    'tk': '6422,1331',
#    'tien': 208000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 10, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoạ 0150206',
#    'tk': '6422,1331',
#    'tien': 22000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 10, 10, 0, 0),
#    'lyDo': 'Trả tiền tiếp khách HĐ 42586',
#    'tk': '6422',
#    'tien': 2500000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00014': {'date': datetime.datetime(2018, 10, 12, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2378',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00019': {'date': datetime.datetime(2018, 10, 15, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2376',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00003': {'date': datetime.datetime(2018, 10, 15, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0002792',
#    'tk': '152,1331',
#    'tien': 4775000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'GBNO-00002': {'date': datetime.datetime(2018, 10, 16, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 50000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00004': {'date': datetime.datetime(2018, 10, 16, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 00332',
#    'tk': '152,1331',
#    'tien': 1881000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00023': {'date': datetime.datetime(2018, 10, 17, 0, 0),
#    'lyDo': 'Sửa chữa xe 92E-0729',
#    'tk': '5113,33311',
#    'tien': 990000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00005': {'date': datetime.datetime(2018, 10, 17, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư HĐ 0171753',
#    'tk': '1547,1331',
#    'tien': 2275000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00025': {'date': datetime.datetime(2018, 10, 18, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-4753',
#    'tk': '5113,33311',
#    'tien': 13838000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00007': {'date': datetime.datetime(2018, 10, 18, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 50000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'GBNO-00006': {'date': datetime.datetime(2018, 10, 19, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 15000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00005': {'date': datetime.datetime(2018, 10, 19, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0000752',
#    'tk': '152,152,1331',
#    'tien': 16289900.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 10, 19, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ 0257900',
#    'tk': '6422,1331',
#    'tien': 197000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00007': {'date': datetime.datetime(2018, 10, 19, 0, 0),
#    'lyDo': 'Trả tiền nướ sinh hoạt HĐ 0479467',
#    'tk': '6422,1331',
#    'tien': 156185.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00026': {'date': datetime.datetime(2018, 10, 22, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2373',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00027': {'date': datetime.datetime(2018, 10, 23, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2374',
#    'tk': '5113,33311',
#    'tien': 792000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00028': {'date': datetime.datetime(2018, 10, 23, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-1353',
#    'tk': '5113,33311',
#    'tien': 693000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00029': {'date': datetime.datetime(2018, 10, 23, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2165',
#    'tk': '5113,33311',
#    'tien': 957000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00030': {'date': datetime.datetime(2018, 10, 24, 0, 0),
#    'lyDo': 'Sửa chữa xe 92C-115.84',
#    'tk': '5113,33311',
#    'tien': 12463000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00008': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 100000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00012': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'nộp tiền vào Tài khoản',
#    'tk': '1121',
#    'tien': 100002000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'NNVL-00008': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 00350',
#    'tk': '152,1331',
#    'tien': 7480000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'NNVL-00009': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0002796',
#    'tk': '152,1331',
#    'tien': 5220000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'Trả tiền in hóa đơn GTGT HĐ 0017971',
#    'tk': '6422,1331',
#    'tien': 1700000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00009': {'date': datetime.datetime(2018, 10, 25, 0, 0),
#    'lyDo': 'Trả tiền tiếp khách HĐ 42990',
#    'tk': '6422',
#    'tien': 1491000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00010': {'date': datetime.datetime(2018, 10, 26, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư HĐ 0178465',
#    'tk': '1547,1331',
#    'tien': 2261000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'GBNO-00013': {'date': datetime.datetime(2018, 10, 28, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00034': {'date': datetime.datetime(2018, 10, 29, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-1399',
#    'tk': '5113,33311',
#    'tien': 693000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00036': {'date': datetime.datetime(2018, 10, 29, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2375',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00014': {'date': datetime.datetime(2018, 10, 30, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00016': {'date': datetime.datetime(2018, 10, 31, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 30000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00013': {'date': datetime.datetime(2018, 10, 31, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 00370',
#    'tk': '152,1331',
#    'tien': 8167500.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00011': {'date': datetime.datetime(2018, 10, 31, 0, 0),
#    'lyDo': 'Trả tiền tiếp khách HĐ 0042591',
#    'tk': '6422',
#    'tien': 3500000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00012': {'date': datetime.datetime(2018, 10, 31, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư phụ tùng ',
#    'tk': '331',
#    'tien': 5054050.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00013': {'date': datetime.datetime(2018, 10, 31, 0, 0),
#    'lyDo': 'Thanh toán tiền lương, tiền công tháng 10/2018',
#    'tk': '334',
#    'tien': 37304000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'}},
#  '11-2018': {'GBNO-00001': {'date': datetime.datetime(2018, 11, 2, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 15000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00003': {'date': datetime.datetime(2018, 11, 5, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 6000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00001': {'date': datetime.datetime(2018, 11, 5, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại, internet HĐ 0299177,0350314',
#    'tk': '6422,1331',
#    'tien': 215911.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00002': {'date': datetime.datetime(2018, 11, 7, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2380',
#    'tk': '5113,33311',
#    'tien': 792000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00003': {'date': datetime.datetime(2018, 11, 7, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-004.18',
#    'tk': '5113,33311',
#    'tien': 8833000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00005': {'date': datetime.datetime(2018, 11, 8, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2212',
#    'tk': '5113,33311',
#    'tien': 693000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00006': {'date': datetime.datetime(2018, 11, 8, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2080',
#    'tk': '5113,33311',
#    'tien': 957000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00008': {'date': datetime.datetime(2018, 11, 12, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2381',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00010': {'date': datetime.datetime(2018, 11, 13, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2379',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBCO-00004': {'date': datetime.datetime(2018, 11, 13, 0, 0),
#    'lyDo': 'nộp tiền vào TK',
#    'tk': '1121',
#    'tien': 26000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'GBNO-00007': {'date': datetime.datetime(2018, 11, 14, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 6000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00004': {'date': datetime.datetime(2018, 11, 14, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0001326',
#    'tk': '152,1331',
#    'tien': 7208412.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00015': {'date': datetime.datetime(2018, 11, 15, 0, 0),
#    'lyDo': 'Sửa chữa xe 57M-3437',
#    'tk': '5113,33311',
#    'tien': 8811000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'GBNO-00008': {'date': datetime.datetime(2018, 11, 15, 0, 0),
#    'lyDo': 'rút tiền mặt nhập quỹ',
#    'tk': '1121',
#    'tien': 4000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00021': {'date': datetime.datetime(2018, 11, 21, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2523',
#    'tk': '5113,33311',
#    'tien': 693000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00002': {'date': datetime.datetime(2018, 11, 23, 0, 0),
#    'lyDo': 'Trả tiền cước điện thoại HĐ 0261932',
#    'tk': '6422,1331',
#    'tien': 171694.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00003': {'date': datetime.datetime(2018, 11, 23, 0, 0),
#    'lyDo': 'Trả tiền nguyên vật iệu HĐ 0200100',
#    'tk': '1547,1331',
#    'tien': 2034000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00031': {'date': datetime.datetime(2018, 11, 26, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-1495',
#    'tk': '5113,33311',
#    'tien': 693000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00032': {'date': datetime.datetime(2018, 11, 26, 0, 0),
#    'lyDo': 'Sửa chữa xe 92E-0729',
#    'tk': '5113,33311',
#    'tien': 990000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00035': {'date': datetime.datetime(2018, 11, 28, 0, 0),
#    'lyDo': 'Sửa chữa xe 76M-1492',
#    'tk': '5113,33311',
#    'tien': 3685000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'NNVL-00012': {'date': datetime.datetime(2018, 11, 29, 0, 0),
#    'lyDo': 'mua vật tư phụ tùng HĐ 0000799',
#    'tk': '152,1331',
#    'tien': 13324300.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00004': {'date': datetime.datetime(2018, 11, 29, 0, 0),
#    'lyDo': 'Trả tiền nước sinh hoạt HĐ 0533913',
#    'tk': '6422,1331',
#    'tien': 531030.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00005': {'date': datetime.datetime(2018, 11, 29, 0, 0),
#    'lyDo': 'Trả tiền tiếp khách HĐ 0009082',
#    'tk': '6422',
#    'tien': 2201000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00006': {'date': datetime.datetime(2018, 11, 29, 0, 0),
#    'lyDo': 'Trả tiền cước phí môi trường HĐ 0006252',
#    'tk': '6422,1331',
#    'tien': 660000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'DTDV-00039': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Sửa chữa xe 92K-5455',
#    'tk': '5113,33311',
#    'tien': 2255000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'DTDV-00040': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Sửa chữa xe VT-2374',
#    'tk': '5113,33311',
#    'tien': 1100000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00001': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'nhận nợ vốn vay ',
#    'tk': '3411',
#    'tien': 50000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PT-00002': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Thu tiền sửa xe 92A-058.65,92A-067.65,92A-001.25',
#    'tk': '131',
#    'tien': 12815000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuThu'},
#   'PC-00007': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư phụ tùng ',
#    'tk': '331',
#    'tien': 9624000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00008': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư',
#    'tk': '331',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00009': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư',
#    'tk': '331',
#    'tien': 8000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00010': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Thanh toán tiền lương, tiền công tháng 11/2018',
#    'tk': '334',
#    'tien': 36466000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'},
#   'PC-00011': {'date': datetime.datetime(2018, 11, 30, 0, 0),
#    'lyDo': 'Trả tiền mua vật tư phụ tùng ',
#    'tk': '331',
#    'tien': 10000000.0,
#    'kemTheo': '',
#    'hoTen': '',
#    'diaChi': '',
#    'loai': 'phieuChi'}}}

# %% [markdown]
# # XLWT and copy

# %%
from xlutils.copy import copy # http://pypi.python.org/pypi/xlutils
from copy import deepcopy
import xlwt
from xlwt import Workbook
from datetime import datetime
print('60%')

# %% [markdown]
# ## Write soure \[DanhSachTen\] to destination

# %% [markdown]
# ### Formating and constant

# %%
FONT_SIZE_UNIT = 20

styles = {
    # 'datetime': xlwt.easyxf(num_format_str='yyyy-mm-dd hh:mm:ss'),
    # 'date': xlwt.easyxf(num_format_str='yyyy-mm-dd'),
    'time':  xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}, italic on; align: wrap true, horiz right, vert center" ),
    'time2' : xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}, italic on; align: wrap true, horiz left, vert center" ), 
    'header': xlwt.easyxf(f"font: name Tahoma, height {11*FONT_SIZE_UNIT}, bold on; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'small_header' : xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}, bold on; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'small_default' : xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'name' : xlwt.easyxf(f"font: name Times New Roman, height {9*FONT_SIZE_UNIT}, bold on; align: wrap true, horiz center, vert bottom", num_format_str='#,##0.00'),
    'default': xlwt.easyxf(f"font: name Tahoma, height {11*FONT_SIZE_UNIT}; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'title': xlwt.easyxf(f"font: name Tahoma, height {15*FONT_SIZE_UNIT}, bold on; align: wrap true, horiz center, vert center", num_format_str='#,##0.00'),
    'footer': xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'medium_default': xlwt.easyxf(f"font: name Tahoma, height {10*FONT_SIZE_UNIT}; align: wrap true, horiz left, vert center", num_format_str='#,##0.00'),
    'small_header_cent' : xlwt.easyxf(f"font: name Tahoma, height {9*FONT_SIZE_UNIT}, bold on; align: wrap true, horiz center, vert center", num_format_str='#,##0.00'),
    }
print('70%')

# %% [markdown]
# ### Hàm Tạo Phiếu thu/chi

# %%
def TaoPhieu(iD, date_ID, w_sheet):
    #----------------------------- Data from DanhSachTen from sheet 1 in Du lieu dau vao.xls ---------------------------#
    w_sheet.write(0, 0, arr[0], styles['header'])                # Ten doanh nghiep
    w_sheet.write(2, 0, arr[1], styles['small_header']),         # Dia chi
    w_sheet.write(21, 20, arr[2], styles['name']),               # Giam doc
    w_sheet.write(21, 14, arr[3], styles['name']),               # Ke toan truong
    w_sheet.write(21, 3, arr[4], styles['name']),                # Nguoi lap Phieu
    w_sheet.write(21, 6, arr[5], styles['name']),                # Thu quy
    
    date    = rows_by_month[date_ID][iD]['date']
    lyDo    = rows_by_month[date_ID][iD]['lyDo']
    tk      = rows_by_month[date_ID][iD]['tk']
    tien    = rows_by_month[date_ID][iD]['tien']
    kemTheo  = rows_by_month[date_ID][iD]['kemTheo']
    hoTen   = rows_by_month[date_ID][iD]['hoTen']
    diaChi  = rows_by_month[date_ID][iD]['diaChi']
    loai    = rows_by_month[date_ID][iD]['loai']
    
    if loai == 'phieuThu':
        availID = tk
        debtID  = '111'
    else: 
        availID = '111'
        debtID  = tk

    #----------------------------------------------- DAY / MONTH / YEAR -----------------------------------------------#

    zeroDay = '0' if date.day / 10 < 1.0 else ''
    zeroMonth = '0' if date.month / 10 < 1.0 else ''

    w_sheet.write(8,7, f'{zeroDay}{date.day}', styles['time2'])
    w_sheet.write(8,10, f'{zeroMonth}{date.month}', styles['time2'])
    w_sheet.write(8,13, date.year, styles['time2'])
    w_sheet.write(18,14, f'Ngày  {zeroDay}{date.day}  tháng  {zeroMonth}{date.month}  năm  {date.year} ', styles['time'])
    
    #----------------------------------------------- phieuID/ So No/ So Co --------------------------------------------#

    w_sheet.write(5, 19, iD, styles['small_default'])
    w_sheet.write(6, 19, debtID, styles['small_default'])
    w_sheet.write(9, 19, availID, styles['small_default'])

    #------------------------------------  HoTen/ Dia Chi/ Ly do/ So tien/ Kem theo -----------------------------------#

    w_sheet.write(12, 4, hoTen, styles['default'])
    w_sheet.write(13, 1, diaChi, styles['default'])
    if loai == 'phieuThu':
        w_sheet.write(5, 7, 'PHIẾU THU', styles['title'])
        w_sheet.write(0, 21, 'Mẫu số 01-TT', styles['small_header_cent'])
        w_sheet.write(14, 0, f'Lý do nộp: {lyDo}', styles['default'])
        w_sheet.write(12, 0, 'Họ và tên người nộp tiền:', styles['default'])
        w_sheet.write(19, 0, 'Người nộp tiền', styles['small_header_cent'])
    else:
        w_sheet.write(5, 7, 'PHIẾU CHI', styles['title'])
        w_sheet.write(0, 21, 'Mẫu số 02-TT', styles['small_header_cent'])
        w_sheet.write(14, 0, f'Lý do chi: {lyDo}', styles['default'])
        w_sheet.write(12, 0, 'Họ và tên người nhận tiền:', styles['default'])
        w_sheet.write(19, 0, 'Người nhận tiền', styles['small_header_cent'])
        
    if int(tien) == 0:
        print(f'Chu y: {date_ID} {iD} co so tien bang 0!')
    w_sheet.write(15, 1, f'{VND(tien)}. (Viết bằng chữ): {Convert(str(int(tien)))}.', styles['default'])
    w_sheet.write(16, 0, f'Kèm theo {kemTheo} chứng từ gốc', styles['default'])
    #----------------------------------------- Chu Ky nguoi nhan tien ------------------------------------------------#

    w_sheet.write(21, 0, hoTen, styles['name'])

    #---------------------------------------------Da Nhan Du Tien ----------------------------------------------------#

    w_sheet.write(23, 0, f'Đã nhận đủ số tiền(viết bằng chữ): {Convert(str(int(tien)))}.', styles['footer'])

    return loai
print('80%')

# %% [markdown]
# ### Tổng hợp các sheet lại thành 1 file

# %%
def TongHop():
    # try:
        wb_chi = copy(ex) # a writable copy (I can't read values out of this, only write to it)
        wb_thu = copy(ex)

        demChi = 0
        demThu = 0
        stopPhieuThu = False
        stopPhieuChi = False
        for month in rows_by_month:
            for phieu in rows_by_month[month]:
                if (stopPhieuThu == False) and (demThu == ex.nsheets - 1):
                    print("Phieu Thu da toi gioi han, xin hay tao them sheet moi")
                    stopPhieuThu = True
                if (stopPhieuChi == False) and (demChi == ex.nsheets - 1):
                    print("Phieu Chi da toi gioi han, xin hay tao them sheet moi")
                    stopPhieuChi = True
                if (stopPhieuThu == False) and (rows_by_month[month][phieu]['loai'] == 'phieuThu'):
                    w_sheet = wb_thu.get_sheet(demThu)
                    demThu += 1
                elif (stopPhieuChi ==False) and (rows_by_month[month][phieu]['loai'] == 'phieuChi'):
                    w_sheet = wb_chi.get_sheet(demChi)
                    demChi += 1
                else:
                    break
                w_sheet.set_name(month + ' ' + phieu)
                # ? This code works if I fix built-in code of Python3, it is not safe for run in other computers now.
                # w_sheet.header_str = '' 
                # w_sheet.footer_str = ''
                TaoPhieu(phieu, month, w_sheet)        
            if stopPhieuThu == True and stopPhieuChi == True:
                break
        print('90%')
        return wb_thu, wb_chi
# Out:
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng
# Không đồng

# %% [markdown]
# ### Lưu lại file tổng

# %%
try:
    wb_thu, wb_chi = TongHop()
    File_PhieuThu = 'Phiếu Thu.xls'
    wb_thu.save(File_PhieuThu)
    File_PhieuChi = 'Phiếu Chi.xls'
    wb_chi.save(File_PhieuChi)
    print('100%')
    print("Da hoan tat chuong trinh")
except Exception as e:
    if 'Permission denied' in str(e):
        print('Loi he thong: Hay kiem tra da dong Phieu Thu.xls va Phieu Chi.xls truoc khi chay chua?')
    else: 
        print('Loi chua xac dinh')
    print('Chua Hoan tat!')
